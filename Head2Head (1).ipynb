# %%
import pandas as pd;
import numpy as np;


file_path = 'database_24_25.csv'
nba_data = pd.read_csv(file_path)

# %%
print("First 10 row of the dataset:")
print(nba_data.head(10));
# Out:
# First 10 row of the dataset:
#           Player   Tm  Opp Res     MP  FG  FGA    FG%  3P  3PA  ...  DRB  TRB  \
# 0   Jayson Tatum  BOS  NYK   W  30.30  14   18  0.778   8   11  ...    4    4
# 1  Anthony Davis  LAL  MIN   W  37.58  11   23  0.478   1    3  ...   13   16
# 2  Derrick White  BOS  NYK   W  26.63   8   13  0.615   6   10  ...    3    3
# 3   Jrue Holiday  BOS  NYK   W  30.52   7    9  0.778   4    6  ...    2    4
# 4  Miles McBride  NYK  BOS   L  25.85   8   10  0.800   4    5  ...    0    0
# 5  Rui Hachimura  LAL  MIN   W  35.08   7   14  0.500   1    4  ...    2    5
# 6   Jaylen Brown  BOS  NYK   W  29.90   7   18  0.389   5    9  ...    5    7
# 7    Rudy Gobert  MIN  LAL   L  35.33   5    8  0.625   0    0  ...   11   14
# 8  Julius Randle  MIN  LAL   L  34.32   5   10  0.500   1    3  ...    6    9
# 9     Al Horford  BOS  NYK   W  26.08   4    7  0.571   3    5  ...    3    3
#
#    AST  STL  BLK  TOV  PF  PTS  GmSc        Data
# ...

# %%
#Show the datatypes and nulls
nba_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16512 entries, 0 to 16511
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  16512 non-null  object
#  1   Tm      16512 non-null  object
#  2   Opp     16512 non-null  object
#  3   Res     16512 non-null  object
#  4   MP      16512 non-null  float64
#  5   FG      16512 non-null  int64
#  6   FGA     16512 non-null  int64
#  7   FG%     16512 non-null  float64
#  8   3P      16512 non-null  int64
#  9   3PA     16512 non-null  int64
#  10  3P%     16512 non-null  float64
#  11  FT      16512 non-null  int64
#  12  FTA     16512 non-null  int64
#  13  FT%     16512 non-null  float64
#  14  ORB     16512 non-null  int64
#  15  DRB     16512 non-null  int64
#  16  TRB     16512 non-null  int64
#  17  AST     16512 non-null  int64
#  18  STL     16512 non-null  int64
#  19  BLK     16512 non-null  int64
#  20  TOV     16512 non-null  int64
# ...

# %%
#Check for missing values
print('Prints missing value in each column:')
print(nba_data.isnull().sum());
# Out:
# Prints missing value in each column:
# Player    0
# Tm        0
# Opp       0
# Res       0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# GmSc      0
# Data      0
# dtype: int64

# %%
print("Displaying dataset to help detect misleading data:")
print(nba_data.describe())
# Out:
# Displaying dataset to help detect misleading data:
#                  MP            FG           FGA           FG%            3P  \
# count  16512.000000  16512.000000  16512.000000  16512.000000  16512.000000
# mean      22.405259      3.848958      8.271742      0.427527      1.250061
# std       10.896645      3.255864      6.071434      0.254938      1.523651
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       14.427500      1.000000      4.000000      0.286000      0.000000
# 50%       23.430000      3.000000      7.000000      0.444000      1.000000
# 75%       31.322500      6.000000     12.000000      0.571000      2.000000
# max       50.480000     22.000000     38.000000      1.000000     10.000000
#
#                 3PA           3P%            FT           FTA           FT%  \
# count  16512.000000  16512.000000  16512.000000  16512.000000  16512.000000
# mean       3.477955      0.263719      1.572917      2.016897      0.417737
# ...

# %%
#Only include players with minutes played more then 0.
nba_data = nba_data[nba_data['MP'] > 0]
                    

#Preprocessing: checking for missing values after.
print('Prints missing value in each column:')
print(nba_data.isnull().sum());
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Only include players with minutes played more then 0.
# ----> 2 nba_data = nba_data[nba_data['MP'] > 0]
#       5 #Preprocessing: checking for missing values after.
#       6 print('Prints missing value in each column:')
#
# NameError: name 'nba_data' is not defined

# %%
# MatPlot Installation
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# Points (PTS)
plt.figure(figsize=(10,6))
sns.histplot(nba_data['PTS'], bins=30, kde=True)
plt.title('Distribution of Player Points per Game')
plt.xlabel('Points per Game')
plt.ylabel('Number of Games')
plt.grid(True)
plt.show()

# Minutes Played (MP)
plt.figure(figsize=(10,6))
sns.histplot(nba_data['MP'], bins=30, kde=True)
plt.title('Distribution of Minutes Played per Game')
plt.xlabel('Minutes Played per Game')
plt.ylabel('Number of Games')
plt.grid(True)
plt.show()

# Assists (AST)
plt.figure(figsize=(10,6))
sns.histplot(nba_data['AST'], bins=30, kde=True)
plt.title('Distribution of Assists per Game')
plt.xlabel('Assists per Game')
plt.ylabel('Number of Games')
plt.grid(True)
plt.show()

# Rebounds (TRB)
plt.figure(figsize=(10,6))
sns.histplot(nba_data['TRB'], bins=30, kde=True)
plt.title('Distribution of Rebounds per Game')
plt.xlabel('Rebounds per Game')
plt.ylabel('Number of Games')
plt.grid(True)
plt.show()

# Turnovers (TOV)
plt.figure(figsize=(10,6))
sns.histplot(nba_data['TOV'], bins=30, kde=True)
plt.title('Distribution of Turnovers per Game')
plt.xlabel('Turnovers per Game')
plt.ylabel('Number of Games')
plt.grid(True)
plt.show()

# Game Score (GmSc)
plt.figure(figsize=(10,6))
sns.histplot(nba_data['GmSc'], bins=30, kde=True)
plt.title('Distribution of Game Performance Score (GmSc)')
plt.xlabel('Game Score')
plt.ylabel('Number of Games')
plt.grid(True)
plt.show()

# %%
plt.show()

nba_data.to_csv('nba_cleaned.csv', index=False)
